# %%
import pyscancf as pcf
import pyart
import matplotlib.pyplot as plt
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# ## Cite PyScanCf:
#
# ## Syed, H. A.,Sayyed, I., Kalapureddy, M. C. R., & Grandhi, K. K.(2021).
# ## PyScanCf – The library for individual sweep datasets of IMD weather radars.
# ## Zenodo. doi:10.5281/zenodo.5574160.

# %%
input_folder = "/Users/syed44/Downloads/Git_Stuff/imd_temp_radar/B/"
output_folder = "/Users/syed44/Downloads/Git_Stuff/imd_temp_radar/out2/"

# %%
ls $input_folder
# Out:
# GOA210516024101-IMD-B.nc*   GOA210516030244-IMD-B.nc*
# GOA210516024101-IMD-B.nc.1* GOA210516030244-IMD-B.nc.1*
# GOA210516024101-IMD-B.nc.2* GOA210516030244-IMD-B.nc.2*
# GOA210516024101-IMD-B.nc.3* GOA210516030244-IMD-B.nc.3*
# GOA210516024101-IMD-B.nc.4* GOA210516030244-IMD-B.nc.4*
# GOA210516024101-IMD-B.nc.5* GOA210516030244-IMD-B.nc.5*
# GOA210516024101-IMD-B.nc.6* GOA210516030244-IMD-B.nc.6*
# GOA210516024101-IMD-B.nc.7* GOA210516030244-IMD-B.nc.7*
# GOA210516024101-IMD-B.nc.8* GOA210516030244-IMD-B.nc.8*
# GOA210516024101-IMD-B.nc.9* GOA210516030244-IMD-B.nc.9*

# %%
pcf.cfrad(input_dir=input_folder, output_dir=output_folder,
          scan_type="B", nf=10, gridder=True, plot="REF")
# Out:
# Number of files:  20
# Total number of files will be created:  2
# Merging all scans in one file
# ...............................
# Plotting Max-REF 20210516024104
# ...............................
#
# ...............................
# Plotting Max-REF 20210516030306
# ...............................
#
# Data merging done
# Total Time Elapsed:  0:00:39.770153

# %%
ls -lth $output_folder
# Out:
# total 262208
# -rw-r--r--  1 syed44  staff    53M Sep  7 23:24 grid_GOA210516030244-IMD-B.nc
# -rw-r--r--  1 syed44  staff   9.8M Sep  7 23:24 cfrad_GOA210516030244-IMD-B.nc
# -rw-r--r--  1 syed44  staff    54M Sep  7 23:23 grid_GOA210516024101-IMD-B.nc
# -rw-r--r--  1 syed44  staff    10M Sep  7 23:23 cfrad_GOA210516024101-IMD-B.nc

# %%
grid = pyart.io.read_grid(output_folder+"grid_GOA210516024101-IMD-B.nc")

# %%
with plt.style.context(['dark_background']):
    pcf.plot_cappi(grid, 'REF', vmin=-20, vmax=65, cmap='SyedSpectral')
plt.show()
# Out:
# ...............................
# Plotting Max-REF 20210516024104
# ...............................

# %%
input_folder = "/Users/syed44/Downloads/Git_Stuff/imd_temp_radar/dualpol/"
output_folder = "/Users/syed44/Downloads/Git_Stuff/imd_temp_radar/out2/"

# %%
ls $input_folder
# Out:
# DLI190724051233-IMD-B.nc*   DLI190724052230-IMD-B.nc*
# DLI190724051233-IMD-B.nc.1* DLI190724052230-IMD-B.nc.1*
# DLI190724051233-IMD-B.nc.2* DLI190724052230-IMD-B.nc.2*
# DLI190724051233-IMD-B.nc.3* DLI190724052230-IMD-B.nc.3*
# DLI190724051233-IMD-B.nc.4* DLI190724052230-IMD-B.nc.4*
# DLI190724051233-IMD-B.nc.5* DLI190724052230-IMD-B.nc.5*
# DLI190724051233-IMD-B.nc.6* DLI190724052230-IMD-B.nc.6*
# DLI190724051233-IMD-B.nc.7* DLI190724052230-IMD-B.nc.7*
# DLI190724051233-IMD-B.nc.8* DLI190724052230-IMD-B.nc.8*
# DLI190724051233-IMD-B.nc.9* DLI190724052230-IMD-B.nc.9*

# %%
pcf.cfrad(input_dir=input_folder, output_dir=output_folder,
          scan_type="B", nf=10, gridder=True, dualpol=True, plot='REF')
# Out:
# Number of files:  20
# Total number of files will be created:  2
# Merging all scans in one file
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /Users/syed44/Downloads/Git_Libs/PyScanCf/Untitled.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/syed44/Downloads/Git_Libs/PyScanCf/Untitled.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> pcf.cfrad(input_dir=input_folder, output_dir=output_folder,
#       <a href='vscode-notebook-cell:/Users/syed44/Downloads/Git_Libs/PyScanCf/Untitled.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>           scan_type="B", nf=10, gridder=True, dualpol=True, plot='REF')
#
# File ~/Downloads/Git_Libs/PyScanCf/pyscancf/pyscancf.py:247, in cfrad(input_dir, output_dir, scan_type, dualpol, gridder, plot, nf)
#     245 out_file = f"cfrad_{fname}.nc"
#     246 out_path = os.path.join(out_dir, out_file)
# --> 247 pyart.io.write_cfradial(out_path, radar, format="NETCDF4")
#     249 if gridder:
#     250     grid = get_grid(radar)
#
# File ~/miniconda3/envs/radar-env/lib/python3.11/site-packages/pyart/io/cfradial.py:489, in write_cfradial(filename, radar, format, include_fields, time_reference, arm_time_variables)
#     434 def write_cfradial(
#     435     filename,
#     436     radar,
#    (...)
#     440     arm_time_variables=False,
#     441 ):
#     442     """
#     443     Write a Radar object to a CF/Radial compliant netCDF file.
#     444
#    (...)
#     487
#     488     """
# --> 489     dataset = netCDF4.Dataset(filename, "w", format=format)
#     491     # determine the maximum string length
#     492     max_str_len = len(radar.sweep_mode["data"][0])
#
# File src/netCDF4/_netCDF4.pyx:2464, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2027, in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: '/Users/syed44/Downloads/Git_Stuff/imd_temp_radar/out2/cfrad_DLI190724051233-IMD-B.nc'

# %%
ls $output_folder
# Out:
# cfrad_DLI190724051233-IMD-B.nc  grid_GOA210515003646-IMD-C.nc
# cfrad_GOA210515003646-IMD-C.nc  grid_GOA210515004746-IMD-C.nc
# cfrad_GOA210515004746-IMD-C.nc  grid_GOA210515005811-IMD-C.nc
# cfrad_GOA210515005811-IMD-C.nc  grid_GOA210516024101-IMD-B.nc
# cfrad_GOA210516024101-IMD-B.nc  grid_GOA210516030244-IMD-B.nc
# cfrad_GOA210516030244-IMD-B.nc

# %%
# !rm -rf $output_folder/cfrad_DLI190724051233-IMD-B.nc

# %%
pcf.cfrad(input_dir=input_folder, output_dir=output_folder,
          scan_type="B", nf=10, gridder=True, dualpol=True, plot='REF')
# Out:
# Number of files:  20
# Total number of files will be created:  2
# Merging all scans in one file
# ...............................
# Plotting Max-REF 20190724051302
# ...............................
#
# ...............................
# Plotting Max-REF 20190724052236
# ...............................
#
# Data merging done
# Total Time Elapsed:  0:07:19.861675

# %%
grid.fields.keys()
# Out:
# dict_keys(['REF', 'VELH', 'WIDTH', 'ROI'])

# %%
with plt.style.context(['dark_background']):
    pcf.plot_cappi(grid, 'VELH', vmin=-70, vmax=70, cmap='SyedSpectral',)
plt.show()
# Out:
# ...............................
# Plotting Max-VELH 20210516024104
# ...............................

# %%
with plt.style.context(['dark_background']):
    pcf.plot_cappi(grid, 'WIDTH', vmin=0, vmax=6, cmap='SyedSpectral',)
plt.show()
# Out:
# ...............................
# Plotting Max-WIDTH 20210516024104
# ...............................
